# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
def percentchange(x, y):
    try:
        return ((x - y)*100/y)
    except ZeroDivisionError:
        return 0
def realchange(x, y):
    return x-y
def percent(x, y):
    return (x/y)*100

# %% [markdown]
# ## This notebook outlines the high level industry data formatting for the Comprehensive Plans with place level primary geographies. There is another document for the information that is pulled for all relevant geographies.

# %% [markdown]
# The Woods & Poole data that is used more at the county level is only used at the place level for total employment projections. This is for consistency. This is a land use model ultimately, so JobsEQ employment is selected to model place level employment for place of work. This data is derived from the QCEW and other inputs so is selected as a better option - both are modeled so we use the one modeled directly from UI claims rather than land use at this granular of a geography.
#
# To retrieve data:
# + Log into JobsEQ and navigate to the "Data Explorer" function
# + Select the "Industry" dataset, annual
# + Select the following dimensions: Region, Industry, Year/Quarter, then select "Employment" as the value
# + Under "Region" select "GNRC Region" and sub "Census Place"
# + For "Year/Quarter" select as many as possible
# + Under "Industry" expand "Total-All Industries" and select 2 digit NAICS codes
#
# This may exceed the drafting size, in which case you'll have to queu for download. Once it is completed, open and delete the top row that says "Industry Data", and delete the third row that repeats "Employment". Rename the FIPS column to GEO_ID, "Time" to "Year", and "Region" to "NAME". Use text to columns to change the GEO_ID column to text. Save in the "Data Downloads" folder as "JobsEQIndustryEmployment_Place.csv"

# %%
data = pd.read_csv('../../Data Downloads/JobsEQIndustryEmployment_Placetest.csv')

# %%
data.head()
# Out:
#           NAME    Year  Total - All Industries  Agriculture, Forestry, Fishing and Hunting (11)  Mining, Quarrying, and Oil and Gas Extraction (21)  \
# 0  GNRC Region  2001.0                833913.0                                           9154.0                                              544.0
# 1  GNRC Region  2002.0                828380.0                                           9122.0                                              484.0
# 2  GNRC Region  2003.0                844281.0                                           8702.0                                              467.0
# 3  GNRC Region  2004.0                865173.0                                           8652.0                                              439.0
# 4  GNRC Region  2005.0                886623.0                                           8463.0                                              550.0
#
#    Utilities (22)  Construction (23)  Manufacturing (31)  Wholesale Trade (42)  Retail Trade (44)  Transportation and Warehousing (48)  \
# 0          4967.0            52041.0            105210.0               36461.0            92291.0                              33036.0
# 1          4936.0            50012.0             99314.0               35301.0            89659.0                              31977.0
# 2          4890.0            52876.0             97117.0               37749.0            92188.0                              33758.0
# 3          4729.0            53160.0             97956.0               37553.0            96070.0                              34691.0
# 4          4723.0            55530.0             97997.0               38552.0            98949.0                              35240.0
#
#    Information (51)  Finance and Insurance (52)  Real Estate and Rental and Leasing (53)  Professional, Scientific, and Technical Services (54)  \
# 0           24400.0                     37052.0                                  15202.0                                            37355.0
# 1           23209.0                     35931.0                                  14402.0                                            38070.0
# 2           21799.0                     36908.0                                  15300.0                                            41033.0
# 3           21040.0                     36820.0                                  14964.0                                            41510.0
# 4           21558.0                     37089.0                                  15330.0                                            43077.0
#
#    Management of Companies and Enterprises (55)  Administrative and Support and Waste Management and Remediation Services (56)  \
# 0                                        5342.0                                            61260.0
# 1                                        6300.0                                            62009.0
# 2                                        6642.0                                            53743.0
# 3                                        7225.0                                            61188.0
# 4                                        7202.0                                            64118.0
#
#    Educational Services (61)  Health Care and Social Assistance (62)  Arts, Entertainment, and Recreation (71)  \
# 0                    53487.0                                 85812.0                                   12839.0
# 1                    55647.0                                 88519.0                                   13160.0
# 2                    58466.0                                 93038.0                                   13908.0
# 3                    62132.0                                 95216.0                                   14213.0
# 4                    64691.0                                 97755.0                                   14648.0
#
#    Accommodation and Food Services (72)  Other Services (except Public Administration) (81)  Public Administration (92)  Unclassified (99)
# 0                               67647.0                                            41599.0                      57873.0              342.0
# 1                               68036.0                                            42987.0                      58987.0              316.0
# 2                               70520.0                                            43828.0                      60833.0              516.0
# 3                               72177.0                                            43886.0                      61072.0              478.0
# 4                               75825.0                                            43523.0                      61470.0              336.0

# %%
data = data.set_index(['NAME'])#, 'GEO_ID'])
cols = data.columns
data[cols] = data[cols].astype(float)

# %%
data.head()
# Out:
#                Year  Total - All Industries  Agriculture, Forestry, Fishing and Hunting (11)  Mining, Quarrying, and Oil and Gas Extraction (21)  \
# NAME
# GNRC Region  2001.0                833913.0                                           9154.0                                              544.0
# GNRC Region  2002.0                828380.0                                           9122.0                                              484.0
# GNRC Region  2003.0                844281.0                                           8702.0                                              467.0
# GNRC Region  2004.0                865173.0                                           8652.0                                              439.0
# GNRC Region  2005.0                886623.0                                           8463.0                                              550.0
#
#              Utilities (22)  Construction (23)  Manufacturing (31)  Wholesale Trade (42)  Retail Trade (44)  Transportation and Warehousing (48)  \
# NAME
# GNRC Region          4967.0            52041.0            105210.0               36461.0            92291.0                              33036.0
# GNRC Region          4936.0            50012.0             99314.0               35301.0            89659.0                              31977.0
# GNRC Region          4890.0            52876.0             97117.0               37749.0            92188.0                              33758.0
# GNRC Region          4729.0            53160.0             97956.0               37553.0            96070.0                              34691.0
# GNRC Region          4723.0            55530.0             97997.0               38552.0            98949.0                              35240.0
#
#              Information (51)  Finance and Insurance (52)  Real Estate and Rental and Leasing (53)  \
# NAME
# GNRC Region           24400.0                     37052.0                                  15202.0
# GNRC Region           23209.0                     35931.0                                  14402.0
# GNRC Region           21799.0                     36908.0                                  15300.0
# GNRC Region           21040.0                     36820.0                                  14964.0
# GNRC Region           21558.0                     37089.0                                  15330.0
#
#              Professional, Scientific, and Technical Services (54)  Management of Companies and Enterprises (55)  \
# NAME
# GNRC Region                                            37355.0                                            5342.0
# GNRC Region                                            38070.0                                            6300.0
# GNRC Region                                            41033.0                                            6642.0
# GNRC Region                                            41510.0                                            7225.0
# GNRC Region                                            43077.0                                            7202.0
#
#              Administrative and Support and Waste Management and Remediation Services (56)  Educational Services (61)  \
# NAME
# GNRC Region                                            61260.0                                                53487.0
# GNRC Region                                            62009.0                                                55647.0
# GNRC Region                                            53743.0                                                58466.0
# GNRC Region                                            61188.0                                                62132.0
# GNRC Region                                            64118.0                                                64691.0
#
#              Health Care and Social Assistance (62)  Arts, Entertainment, and Recreation (71)  Accommodation and Food Services (72)  \
# NAME
# GNRC Region                                 85812.0                                   12839.0                               67647.0
# GNRC Region                                 88519.0                                   13160.0                               68036.0
# GNRC Region                                 93038.0                                   13908.0                               70520.0
# GNRC Region                                 95216.0                                   14213.0                               72177.0
# GNRC Region                                 97755.0                                   14648.0                               75825.0
#
#              Other Services (except Public Administration) (81)  Public Administration (92)  Unclassified (99)
# NAME
# GNRC Region                                            41599.0                      57873.0              342.0
# GNRC Region                                            42987.0                      58987.0              316.0
# GNRC Region                                            43828.0                      60833.0              516.0
# GNRC Region                                            43886.0                      61072.0              478.0
# GNRC Region                                            43523.0                      61470.0              336.0

# %%
#first we will aggregate some of these industries to match our other industry data
data['Total'] = data['Total - All Industries']
data['Natural Resources & Mining'] = data['Agriculture, Forestry, Fishing and Hunting (11)'] + data['Mining, Quarrying, and Oil and Gas Extraction (21)']
data['Construction'] = data['Construction (23)']
data['Manufacturing'] = data['Manufacturing (31)']
thelist = [data['Wholesale Trade (42)'], data['Retail Trade (44)'], data['Transportation and Warehousing (48)'], data['Utilities (22)']]
data['Trade, Transportation, & Utilities'] = sum(thelist)
data['Information'] = data['Information (51)']
thelist = [data['Finance and Insurance (52)'], data['Real Estate and Rental and Leasing (53)']]
data['Financial Activities'] = sum(thelist)
thelist = [data['Professional, Scientific, and Technical Services (54)'], data['Management of Companies and Enterprises (55)'], 
           data['Administrative and Support and Waste Management and Remediation Services (56)']]
data['Professional & Business Services'] = sum(thelist)
thelist = [data['Educational Services (61)'], data['Health Care and Social Assistance (62)']]
data['Education & Health Services'] = sum(thelist)
thelist = [data['Arts, Entertainment, and Recreation (71)'], data['Accommodation and Food Services (72)']]
data['Leisure & Hospitality'] = sum(thelist)
data['Public Administration'] = data['Public Administration (92)']
thelist = [data['Other Services (except Public Administration) (81)'], data['Unclassified (99)']]
data['Other/Unclassified'] = sum(thelist)
thelist = [data['Natural Resources & Mining'], data['Construction'], data['Manufacturing']]
data['Goods Producing'] = sum(thelist)
thelist = [data['Information'], data['Financial Activities'], data['Professional & Business Services'], 
           data['Education & Health Services'], data['Leisure & Hospitality'], data['Public Administration'], data['Other/Unclassified']]
data['Service Producing'] = sum(thelist)

cols = ['Agriculture, Forestry, Fishing and Hunting (11)', 'Mining, Quarrying, and Oil and Gas Extraction (21)', 
        'Wholesale Trade (42)', 'Retail Trade (44)', 'Transportation and Warehousing (48)', 'Utilities (22)', 'Finance and Insurance (52)', 
        'Real Estate and Rental and Leasing (53)', 'Professional, Scientific, and Technical Services (54)', 'Management of Companies and Enterprises (55)', 
        'Administrative and Support and Waste Management and Remediation Services (56)', 'Educational Services (61)', 'Health Care and Social Assistance (62)', 
        'Arts, Entertainment, and Recreation (71)', 'Accommodation and Food Services (72)', 'Other Services (except Public Administration) (81)', 
        'Unclassified (99)', 'Total - All Industries', 'Construction (23)', 'Manufacturing (31)', 'Information (51)', 'Public Administration (92)']
data = data.drop(columns = cols)

# %%
data.head()
# Out:
#                Year     Total  Natural Resources & Mining  Construction  Manufacturing  Trade, Transportation, & Utilities  Information  \
# NAME
# GNRC Region  2001.0  833914.0                      9698.0       52041.0       105210.0                            166755.0      24400.0
# GNRC Region  2002.0  828378.0                      9606.0       50012.0        99314.0                            161873.0      23209.0
# GNRC Region  2003.0  844281.0                      9169.0       52876.0        97117.0                            168585.0      21799.0
# GNRC Region  2004.0  865171.0                      9091.0       53160.0        97956.0                            173043.0      21040.0
# GNRC Region  2005.0  886626.0                      9013.0       55530.0        97997.0                            177464.0      21558.0
#
#              Financial Activities  Professional & Business Services  Education & Health Services  Leisure & Hospitality  Public Administration  \
# NAME
# GNRC Region               52254.0                          103957.0                     139299.0                80486.0                57873.0
# GNRC Region               50333.0                          106379.0                     144166.0                81196.0                58987.0
# GNRC Region               52208.0                          101418.0                     151504.0                84428.0                60833.0
# GNRC Region               51784.0                          109923.0                     157348.0                86390.0                61072.0
# GNRC Region               52419.0                          114397.0                     162446.0                90473.0                61470.0
#
#              Other/Unclassified  Goods Producing  Service Producing
# NAME
# GNRC Region             41941.0         166949.0           500210.0
# GNRC Region             43303.0         158932.0           507573.0
# GNRC Region             44344.0         159162.0           516534.0
# GNRC Region             44364.0         160207.0           531921.0
# GNRC Region             43859.0         162540.0           546622.0

# %%
#resum so that percentages work - data caveat that they would not sum perfectly due to rounding
thelist = [data['Natural Resources & Mining'], data['Construction'], data['Manufacturing'], data['Trade, Transportation, & Utilities'], 
           data['Information'], data['Financial Activities'], data['Professional & Business Services'], data['Education & Health Services'], 
           data['Leisure & Hospitality'], data['Public Administration'], data['Other/Unclassified']]
data['Total'] = sum(thelist)

# %%
cols = data.columns
thing = data.reset_index(drop = False).melt(var_name = 'Industry', id_vars = ['NAME', 'Year'], value_vars = cols, value_name = 'Employment')
thing.head()
# Out:
#           NAME    Year Industry  Employment
# 0  GNRC Region  2001.0    Total    833914.0
# 1  GNRC Region  2002.0    Total    828378.0
# 2  GNRC Region  2003.0    Total    844281.0
# 3  GNRC Region  2004.0    Total    865171.0
# 4  GNRC Region  2005.0    Total    886626.0

# %%
percents = data

# %%
percents.head()
# Out:
#                Year     Total  Natural Resources & Mining  Construction  Manufacturing  Trade, Transportation, & Utilities  Information  \
# NAME
# GNRC Region  2001.0  833914.0                      9698.0       52041.0       105210.0                            166755.0      24400.0
# GNRC Region  2002.0  828378.0                      9606.0       50012.0        99314.0                            161873.0      23209.0
# GNRC Region  2003.0  844281.0                      9169.0       52876.0        97117.0                            168585.0      21799.0
# GNRC Region  2004.0  865171.0                      9091.0       53160.0        97956.0                            173043.0      21040.0
# GNRC Region  2005.0  886626.0                      9013.0       55530.0        97997.0                            177464.0      21558.0
#
#              Financial Activities  Professional & Business Services  Education & Health Services  Leisure & Hospitality  Public Administration  \
# NAME
# GNRC Region               52254.0                          103957.0                     139299.0                80486.0                57873.0
# GNRC Region               50333.0                          106379.0                     144166.0                81196.0                58987.0
# GNRC Region               52208.0                          101418.0                     151504.0                84428.0                60833.0
# GNRC Region               51784.0                          109923.0                     157348.0                86390.0                61072.0
# GNRC Region               52419.0                          114397.0                     162446.0                90473.0                61470.0
#
#              Other/Unclassified  Goods Producing  Service Producing
# NAME
# GNRC Region             41941.0         166949.0           500210.0
# GNRC Region             43303.0         158932.0           507573.0
# GNRC Region             44344.0         159162.0           516534.0
# GNRC Region             44364.0         160207.0           531921.0
# GNRC Region             43859.0         162540.0           546622.0

# %%
#first we will aggregate some of these industries to match our other industry data
percents['Natural Resources & Mining'] = percent(percents['Natural Resources & Mining'], percents['Total'])
percents['Construction'] = percent(percents['Construction'], percents['Total'])
percents['Manufacturing'] = percent(percents['Manufacturing'], percents['Total'])
percents['Trade, Transportation, & Utilities'] = percent(percents['Trade, Transportation, & Utilities'], percents['Total'])
percents['Information'] = percent(percents['Information'], percents['Total'])
percents['Financial Activities'] = percent(percents['Financial Activities'], percents['Total'])
percents['Professional & Business Services'] = percent(percents['Professional & Business Services'], percents['Total'])
percents['Education & Health Services'] = percent(percents['Education & Health Services'], percents['Total'])
percents['Leisure & Hospitality'] = percent(percents['Leisure & Hospitality'], percents['Total'])
percents['Public Administration'] = percent(percents['Public Administration'], percents['Total'])
percents['Other/Unclassified'] = percent(percents['Other/Unclassified'], percents['Total'])
percents['Goods Producing'] = percent(percents['Goods Producing'], percents['Total'])
percents['Service Producing'] = percent(percents['Service Producing'], percents['Total'])

# %%
thing.head()
# Out:
#           NAME    Year Industry  Employment
# 0  GNRC Region  2001.0    Total    833914.0
# 1  GNRC Region  2002.0    Total    828378.0
# 2  GNRC Region  2003.0    Total    844281.0
# 3  GNRC Region  2004.0    Total    865171.0
# 4  GNRC Region  2005.0    Total    886626.0

# %%
cols = percents.columns
percents = percents.reset_index(drop = False).melt(var_name = 'Industry', id_vars = ['NAME', 'Year'], value_vars = cols, value_name = 'Percent of Employment')
percents.head()
# Out:
#           NAME    Year Industry  Percent of Employment
# 0  GNRC Region  2001.0    Total               833914.0
# 1  GNRC Region  2002.0    Total               828378.0
# 2  GNRC Region  2003.0    Total               844281.0
# 3  GNRC Region  2004.0    Total               865171.0
# 4  GNRC Region  2005.0    Total               886626.0

# %%
percents = percents.set_index('Industry').transpose()
percents = percents.drop(columns = 'Total')
percents = percents.transpose().reset_index(drop = False)

# %%
df = thing.merge(percents, on = ['Industry', 'Year', 'NAME'], how = 'outer')
df.head(20)
# Out:
#            NAME    Year Industry  Employment Percent of Employment
# 0   GNRC Region  2001.0    Total    833914.0                   NaN
# 1   GNRC Region  2002.0    Total    828378.0                   NaN
# 2   GNRC Region  2003.0    Total    844281.0                   NaN
# 3   GNRC Region  2004.0    Total    865171.0                   NaN
# 4   GNRC Region  2005.0    Total    886626.0                   NaN
# 5   GNRC Region  2006.0    Total    910451.0                   NaN
# 6   GNRC Region  2007.0    Total    918193.0                   NaN
# 7   GNRC Region  2008.0    Total    907869.0                   NaN
# 8   GNRC Region  2009.0    Total    866292.0                   NaN
# 9   GNRC Region  2010.0    Total    868743.0                   NaN
# 10  GNRC Region  2011.0    Total    885491.0                   NaN
# 11  GNRC Region  2012.0    Total    913111.0                   NaN
# 12  GNRC Region  2013.0    Total    939783.0                   NaN
# 13  GNRC Region  2014.0    Total    972374.0                   NaN
# 14  GNRC Region  2015.0    Total    994179.0                   NaN
# 15  GNRC Region  2016.0    Total   1032916.0                   NaN
# 16  GNRC Region  2017.0    Total   1066151.0                   NaN
# 17  GNRC Region  2018.0    Total   1099643.0                   NaN
# 18  GNRC Region  2019.0    Total   1135540.0                   NaN
# 19  GNRC Region  2020.0    Total   1085889.0                   NaN

# %%
df = df.set_index('NAME').transpose()

# %%
df = df.rename(columns = {'Adams city, TN': 'Adams', 'Ashland City town, TN': 'Ashland City', 'Belle Meade city, TN': 'Belle Meade',
                                    'Berry Hill city, TN': 'Berry Hill', 'Brentwood city, TN': 'Brentwood', 'Burns town, TN': 'Burns',
                                    'Cedar Hill city, TN': 'Cedar Hill', 'Charlotte town, TN': 'Charlotte',
                                    'Cheatham County, TN': 'Cheatham County', 'Clarksville city, TN': 'Clarksville',
                                    'Columbia city, TN': 'Columbia', 'Coopertown town, TN': 'Coopertown',
                                    'Cross Plains city, TN': 'Cross Plains', 'Cumberland City town, TN': 'Cumberland City',
                                    'Davidson County, TN': 'Davidson County', 'Dickson city, TN': 'Dickson',
                                    'Dickson County, TN': 'Dickson County', 'Dover city, TN': 'Dover',
                                    'Eagleville city, TN': 'Eagleville', 'Erin city, TN': 'Erin', 'Fairview city, TN': 'Fairview',
                                    'Forest Hills city, TN': 'Forest Hills', 'Franklin city, TN': 'Franklin', 'Gallatin city, TN': 'Gallatin',
                                    'Goodlettsville city, TN': 'Goodlettsville', 'Greenbrier town, TN': 'Greenbrier',
                                    'Hartsville/Trousdale County, TN': 'Hartsville/Trousdale', 'Hendersonville city, TN': 'Hendersonville',
                                    'Houston County, TN': 'Houston County', 
                                    'Kingston Springs town, TN': 'Kingston Springs', 'La Vergne city, TN': 'La Vergne',
                                    'Lebanon city, TN': 'Lebanon', 'McEwen city, TN': 'McEwen',
                                    'Millersville city, TN': 'Millersville', 'Mitchellville city, TN': 'Mitchellville',
                                    'Montgomery County, TN': 'Montgomery County', 'Mount Juliet city, TN': 'Mount Juliet',
                                    'Mount Pleasant city, TN': 'Mount Pleasant', 'Murfreesboro city, TN': 'Murfreesboro',
                                    'Nashville-Davidson metropolitan government (balance), TN': 'Nashville', 
                                    'New Johnsonville city, TN': 'New Johnsonville', 'Nolensville town, TN': 'Nolensville',
                                    'Oak Hill city, TN': 'Oak Hill', 'Pegram town, TN': 'Pegram', 'Pleasant View city, TN': 'Pleasant View',
                                    'Portland city, TN': 'Portland', 'Ridgetop city, TN': 'Ridgetop',
                                    'Rutherford County, TN': 'Rutherford County', 'Slayden town, TN': 'Slayden', 'Smyrna town, TN': 'Smyrna',
                                    'Spring Hill city, TN': 'Spring Hill', 'Springfield city, TN': 'Springfield',
                                    'Stewart County, TN': 'Stewart County', 'Sumner County, TN': 'Sumner County',
                                    'Tennessee Ridge town, TN': 'Tennessee Ridge', "Thompson's Station town, TN": "Thompson's Station",
                                    'Trousdale County, TN': 'Trousdale County', 'Vanleer town, TN': 'Vanleer', 'Watertown city, TN': 'Watertown',
                                    'Waverly city, TN': 'Waverly', 'Westmoreland town, TN': 'Westmoreland', 'White Bluff town, TN': 'White Bluff',
                                    'White House city, TN': 'White House', 'Williamson County, TN': 'Williamson County',
                                    'Wilson County, TN': 'Wilson County'})
df = df.transpose()
df = df.reset_index()

# %%
df.tail(200)
# Out:
#                                                     NAME    Year           Industry Employment Percent of Employment
# 20730                                    Tennessee Ridge  2015.0  Service Producing       83.0             32.421875
# 20731                                    Tennessee Ridge  2016.0  Service Producing       86.0             38.738739
# 20732                                    Tennessee Ridge  2017.0  Service Producing      108.0             49.769585
# 20733                                    Tennessee Ridge  2018.0  Service Producing      121.0             48.594378
# 20734                                    Tennessee Ridge  2019.0  Service Producing      114.0             48.101266
# 20735                                    Tennessee Ridge  2020.0  Service Producing      115.0             51.339286
# 20736                                    Tennessee Ridge  2021.0  Service Producing      119.0             52.422907
# 20737                                 Thompson's Station  2001.0  Service Producing      346.0             77.927928
# 20738                                 Thompson's Station  2002.0  Service Producing      355.0             78.021978
# 20739                                 Thompson's Station  2003.0  Service Producing      339.0             80.331754
# 20740                                 Thompson's Station  2004.0  Service Producing      366.0             81.879195
# 20741                                 Thompson's Station  2005.0  Service Producing      397.0             78.149606
# 20742                                 Thompson's Station  2006.0  Service Producing      433.0             80.036969
# 20743                                 Thompson's Station  2007.0  Service Producing      488.0             75.894246
# 20744                                 Thompson's Station  2008.0  Service Producing      491.0             76.124031
# 20745                                 Thompson's Station  2009.0  Service Producing      548.0             68.757842
# 20746                                 Thompson's Station  2010.0  Service Producing      506.0              71.97724
# 20747                                 Thompson's Station  2011.0  Service Producing      644.0             61.274976
# 20748                                 Thompson's Station  2012.0  Service Producing      813.0             57.864769
# 20749                                 Thompson's Station  2013.0  Service Producing      813.0             58.237822
# 20750                                 Thompson's Station  2014.0  Service Producing      767.0             56.314244
# 20751                                 Thompson's Station  2015.0  Service Producing      762.0             56.612184
# 20752                                 Thompson's Station  2016.0  Service Producing      758.0             55.776306
# 20753                                 Thompson's Station  2017.0  Service Producing      957.0             58.496333
# 20754                                 Thompson's Station  2018.0  Service Producing      996.0             60.843005
# 20755                                 Thompson's Station  2019.0  Service Producing     1103.0             63.209169
# 20756                                 Thompson's Station  2020.0  Service Producing     1046.0             62.785114
# 20757                                 Thompson's Station  2021.0  Service Producing     1077.0              62.39861
# 20758                                            Vanleer  2001.0  Service Producing       50.0              60.97561
# 20759                                            Vanleer  2002.0  Service Producing       52.0             64.197531
# 20760                                            Vanleer  2003.0  Service Producing       55.0             63.218391
# 20761                                            Vanleer  2004.0  Service Producing       53.0             58.888889
# 20762                                            Vanleer  2005.0  Service Producing       52.0             58.426966
# 20763                                            Vanleer  2006.0  Service Producing       53.0             58.888889
# 20764                                            Vanleer  2007.0  Service Producing       55.0             57.894737
# 20765                                            Vanleer  2008.0  Service Producing       57.0             62.637363
# 20766                                            Vanleer  2009.0  Service Producing       59.0              63.44086
# 20767                                            Vanleer  2010.0  Service Producing       61.0             64.893617
# 20768                                            Vanleer  2011.0  Service Producing       48.0             60.759494
# 20769                                            Vanleer  2012.0  Service Producing       28.0             65.116279
# 20770                                            Vanleer  2013.0  Service Producing       30.0             37.037037
# 20771                                            Vanleer  2014.0  Service Producing       27.0                  30.0
# 20772                                            Vanleer  2015.0  Service Producing       29.0             30.851064
# 20773                                            Vanleer  2016.0  Service Producing       33.0             33.673469
# 20774                                            Vanleer  2017.0  Service Producing       20.0             25.974026
# 20775                                            Vanleer  2018.0  Service Producing       17.0             30.357143
# 20776                                            Vanleer  2019.0  Service Producing       14.0             29.166667
# 20777                                            Vanleer  2020.0  Service Producing       14.0             28.571429
# 20778                                            Vanleer  2021.0  Service Producing       16.0             30.769231
# 20779                               Walnut Grove CDP, TN  2001.0  Service Producing       13.0             18.571429
# 20780                               Walnut Grove CDP, TN  2002.0  Service Producing       14.0             20.588235
# 20781                               Walnut Grove CDP, TN  2003.0  Service Producing        2.0                  10.0
# 20782                               Walnut Grove CDP, TN  2004.0  Service Producing        4.0             28.571429
# 20783                               Walnut Grove CDP, TN  2005.0  Service Producing        7.0                  35.0
# 20784                               Walnut Grove CDP, TN  2006.0  Service Producing       13.0             36.111111
# 20785                               Walnut Grove CDP, TN  2007.0  Service Producing       16.0             48.484848
# 20786                               Walnut Grove CDP, TN  2008.0  Service Producing       11.0                34.375
# 20787                               Walnut Grove CDP, TN  2009.0  Service Producing       12.0             26.086957
# 20788                               Walnut Grove CDP, TN  2010.0  Service Producing       12.0                  48.0
# 20789                               Walnut Grove CDP, TN  2011.0  Service Producing        9.0                  36.0
# 20790                               Walnut Grove CDP, TN  2012.0  Service Producing       13.0             36.111111
# 20791                               Walnut Grove CDP, TN  2013.0  Service Producing       12.0              41.37931
# 20792                               Walnut Grove CDP, TN  2014.0  Service Producing       13.0             54.166667
# 20793                               Walnut Grove CDP, TN  2015.0  Service Producing       10.0             58.823529
# 20794                               Walnut Grove CDP, TN  2016.0  Service Producing       16.0             66.666667
# 20795                               Walnut Grove CDP, TN  2017.0  Service Producing       17.0             41.463415
# 20796                               Walnut Grove CDP, TN  2018.0  Service Producing       15.0             39.473684
# 20797                               Walnut Grove CDP, TN  2019.0  Service Producing       16.0             37.209302
# 20798                               Walnut Grove CDP, TN  2020.0  Service Producing       16.0             37.209302
# 20799                               Walnut Grove CDP, TN  2021.0  Service Producing       18.0             39.130435
# 20800                                 Walterhill CDP, TN  2001.0  Service Producing       31.0             30.097087
# 20801                                 Walterhill CDP, TN  2002.0  Service Producing       33.0             31.428571
# 20802                                 Walterhill CDP, TN  2003.0  Service Producing       35.0             25.179856
# 20803                                 Walterhill CDP, TN  2004.0  Service Producing       38.0             26.760563
# 20804                                 Walterhill CDP, TN  2005.0  Service Producing       39.0             28.888889
# 20805                                 Walterhill CDP, TN  2006.0  Service Producing      329.0             70.752688
# 20806                                 Walterhill CDP, TN  2007.0  Service Producing       51.0             35.416667
# 20807                                 Walterhill CDP, TN  2008.0  Service Producing       54.0             39.705882
# 20808                                 Walterhill CDP, TN  2009.0  Service Producing       55.0             54.455446
# 20809                                 Walterhill CDP, TN  2010.0  Service Producing       61.0             48.031496
# 20810                                 Walterhill CDP, TN  2011.0  Service Producing       57.0             46.721311
# 20811                                 Walterhill CDP, TN  2012.0  Service Producing       50.0             44.247788
# 20812                                 Walterhill CDP, TN  2013.0  Service Producing       52.0             30.952381
# 20813                                 Walterhill CDP, TN  2014.0  Service Producing       47.0             29.936306
# 20814                                 Walterhill CDP, TN  2015.0  Service Producing       46.0             25.988701
# 20815                                 Walterhill CDP, TN  2016.0  Service Producing       59.0             32.417582
# 20816                                 Walterhill CDP, TN  2017.0  Service Producing       58.0             33.333333
# 20817                                 Walterhill CDP, TN  2018.0  Service Producing       60.0             29.411765
# 20818                                 Walterhill CDP, TN  2019.0  Service Producing       64.0             34.972678
# 20819                                 Walterhill CDP, TN  2020.0  Service Producing       66.0             35.869565
# 20820                                 Walterhill CDP, TN  2021.0  Service Producing       68.0             34.693878
# 20821                                          Watertown  2001.0  Service Producing      287.0             75.925926
# 20822                                          Watertown  2002.0  Service Producing      306.0             77.468354
# 20823                                          Watertown  2003.0  Service Producing      295.0             75.255102
# 20824                                          Watertown  2004.0  Service Producing      285.0             72.335025
# 20825                                          Watertown  2005.0  Service Producing      294.0             66.970387
# 20826                                          Watertown  2006.0  Service Producing      324.0              72.64574
# 20827                                          Watertown  2007.0  Service Producing      345.0             72.631579
# 20828                                          Watertown  2008.0  Service Producing      329.0             70.149254
# 20829                                          Watertown  2009.0  Service Producing      298.0             65.350877
# 20830                                          Watertown  2010.0  Service Producing      296.0             61.538462
# 20831                                          Watertown  2011.0  Service Producing      313.0             63.488844
# 20832                                          Watertown  2012.0  Service Producing      319.0             63.293651
# 20833                                          Watertown  2013.0  Service Producing      309.0                  61.8
# 20834                                          Watertown  2014.0  Service Producing      313.0             64.139344
# 20835                                          Watertown  2015.0  Service Producing      303.0             63.522013
# 20836                                          Watertown  2016.0  Service Producing      264.0                  55.0
# 20837                                          Watertown  2017.0  Service Producing      237.0             50.967742
# 20838                                          Watertown  2018.0  Service Producing      238.0             52.422907
# 20839                                          Watertown  2019.0  Service Producing      254.0             54.389722
# 20840                                          Watertown  2020.0  Service Producing      267.0             54.938272
# 20841                                          Watertown  2021.0  Service Producing      284.0             53.483992
# 20842                                            Waverly  2001.0  Service Producing     1061.0             50.911708
# 20843                                            Waverly  2002.0  Service Producing     1083.0              52.26834
# 20844                                            Waverly  2003.0  Service Producing     1126.0             54.501452
# 20845                                            Waverly  2004.0  Service Producing     1239.0             53.405172
# 20846                                            Waverly  2005.0  Service Producing     1323.0             59.945628
# 20847                                            Waverly  2006.0  Service Producing     1340.0             67.676768
# 20848                                            Waverly  2007.0  Service Producing     1274.0             67.693943
# 20849                                            Waverly  2008.0  Service Producing     1253.0             68.582375
# 20850                                            Waverly  2009.0  Service Producing     1232.0             70.886076
# 20851                                            Waverly  2010.0  Service Producing     1241.0             72.446001
# 20852                                            Waverly  2011.0  Service Producing     1264.0             67.449306
# 20853                                            Waverly  2012.0  Service Producing     1142.0             60.583554
# 20854                                            Waverly  2013.0  Service Producing     1119.0             60.782184
# 20855                                            Waverly  2014.0  Service Producing     1111.0             60.743576
# 20856                                            Waverly  2015.0  Service Producing     1226.0             62.423625
# 20857                                            Waverly  2016.0  Service Producing     1280.0              61.21473
# 20858                                            Waverly  2017.0  Service Producing     1351.0             62.344255
# 20859                                            Waverly  2018.0  Service Producing     1439.0             63.983993
# 20860                                            Waverly  2019.0  Service Producing     1432.0             63.985702
# 20861                                            Waverly  2020.0  Service Producing     1412.0              65.34012
# 20862                                            Waverly  2021.0  Service Producing     1400.0             64.784822
# 20863                                       Westmoreland  2001.0  Service Producing      444.0             52.420307
# 20864                                       Westmoreland  2002.0  Service Producing      443.0             53.502415
# 20865                                       Westmoreland  2003.0  Service Producing      438.0             62.393162
# 20866                                       Westmoreland  2004.0  Service Producing      450.0             70.532915
# 20867                                       Westmoreland  2005.0  Service Producing      435.0             72.742475
# 20868                                       Westmoreland  2006.0  Service Producing      433.0             72.046589
# 20869                                       Westmoreland  2007.0  Service Producing      430.0             70.261438
# 20870                                       Westmoreland  2008.0  Service Producing      460.0             68.452381
# 20871                                       Westmoreland  2009.0  Service Producing      510.0             73.699422
# 20872                                       Westmoreland  2010.0  Service Producing      521.0             75.616836
# 20873                                       Westmoreland  2011.0  Service Producing      590.0             74.968234
# 20874                                       Westmoreland  2012.0  Service Producing      589.0             78.533333
# 20875                                       Westmoreland  2013.0  Service Producing      642.0             78.773006
# 20876                                       Westmoreland  2014.0  Service Producing      656.0             78.002378
# 20877                                       Westmoreland  2015.0  Service Producing      687.0             79.421965
# 20878                                       Westmoreland  2016.0  Service Producing      674.0             78.554779
# 20879                                       Westmoreland  2017.0  Service Producing      693.0             79.930796
# 20880                                       Westmoreland  2018.0  Service Producing      672.0             77.687861
# 20881                                       Westmoreland  2019.0  Service Producing      669.0             76.720183
# 20882                                       Westmoreland  2020.0  Service Producing      653.0             76.018626
# 20883                                       Westmoreland  2021.0  Service Producing      670.0              75.87769
# 20884                                        White Bluff  2001.0  Service Producing      210.0                  25.0
# 20885                                        White Bluff  2002.0  Service Producing      205.0              26.11465
# 20886                                        White Bluff  2003.0  Service Producing      227.0             28.094059
# 20887                                        White Bluff  2004.0  Service Producing      240.0             31.209363
# 20888                                        White Bluff  2005.0  Service Producing      256.0             32.364096
# 20889                                        White Bluff  2006.0  Service Producing      278.0             35.189873
# 20890                                        White Bluff  2007.0  Service Producing      253.0             35.734463
# 20891                                        White Bluff  2008.0  Service Producing      260.0             36.312849
# 20892                                        White Bluff  2009.0  Service Producing      259.0             35.382514
# 20893                                        White Bluff  2010.0  Service Producing      241.0              32.30563
# 20894                                        White Bluff  2011.0  Service Producing      256.0             33.551769
# 20895                                        White Bluff  2012.0  Service Producing      240.0             30.927835
# 20896                                        White Bluff  2013.0  Service Producing      257.0             31.303289
# 20897                                        White Bluff  2014.0  Service Producing      251.0             31.532663
# 20898                                        White Bluff  2015.0  Service Producing      253.0             29.834906
# 20899                                        White Bluff  2016.0  Service Producing      252.0             28.603859
# 20900                                        White Bluff  2017.0  Service Producing      264.0             30.913349
# 20901                                        White Bluff  2018.0  Service Producing      286.0              31.60221
# 20902                                        White Bluff  2019.0  Service Producing      298.0              32.14671
# 20903                                        White Bluff  2020.0  Service Producing      274.0             30.960452
# 20904                                        White Bluff  2021.0  Service Producing      281.0             30.981257
# 20905                                        White House  2001.0  Service Producing     1344.0             44.949833
# 20906                                        White House  2002.0  Service Producing     1334.0             44.991568
# 20907                                        White House  2003.0  Service Producing     1388.0             44.091487
# 20908                                        White House  2004.0  Service Producing     1457.0                46.624
# 20909                                        White House  2005.0  Service Producing     1638.0             52.049571
# 20910                                        White House  2006.0  Service Producing     1841.0             56.681034
# 20911                                        White House  2007.0  Service Producing     2036.0             57.303687
# 20912                                        White House  2008.0  Service Producing     2070.0             59.774762
# 20913                                        White House  2009.0  Service Producing     2160.0             64.228368
# 20914                                        White House  2010.0  Service Producing     2190.0             63.811189
# 20915                                        White House  2011.0  Service Producing     2121.0             60.444571
# 20916                                        White House  2012.0  Service Producing     2228.0             59.572193
# 20917                                        White House  2013.0  Service Producing     2316.0             58.543984
# 20918                                        White House  2014.0  Service Producing     2318.0             57.575758
# 20919                                        White House  2015.0  Service Producing     2548.0             59.756098
# 20920                                        White House  2016.0  Service Producing     2563.0             59.232725
# 20921                                        White House  2017.0  Service Producing     2815.0             61.076155
# 20922                                        White House  2018.0  Service Producing     2917.0             61.462284
# 20923                                        White House  2019.0  Service Producing     2918.0             60.614873
# 20924                                        White House  2020.0  Service Producing     2841.0             59.609736
# 20925                                        White House  2021.0  Service Producing     2936.0             60.090053
# 20926                                                NaN     NaN  Service Producing        NaN                   NaN
# 20927    Exported on: Thursday, February 2, 2023 2:56 PM     NaN  Service Producing        NaN                   NaN
# 20928                                    Source: JobsEQ®     NaN  Service Producing        NaN                   NaN
# 20929  Note: Figures may not sum due to rounding. Gro...     NaN  Service Producing        NaN                   NaN

# %%
df.to_csv('../../Outputs/JOBSEQ_INDUSTRYEMP__PLACES_HISTORICALANDCURRENT.csv', index = False)
